# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/superstore_data.csv" , low_memory = False)

# %% [markdown]
# # Objective
# - To understand the dataset structure, analyze column datatypes, and prepare the data for further business analysis and visualization.

# %%
df.shape
# Out:
# (51290, 32)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   category           51290 non-null  object
#  1   city               51290 non-null  object
#  2   country            51290 non-null  object
#  3   customer_id        51290 non-null  object
#  4   customer_name      51290 non-null  object
#  5   discount           51290 non-null  float64
#  6   market             51290 non-null  object
#  7   column             51290 non-null  int64
#  8   order_date         51290 non-null  datetime64[ns]
#  9   order_id           51290 non-null  object
#  10  order_priority     51290 non-null  object
#  11  product_id         51290 non-null  object
#  12  product_name       51290 non-null  object
#  13  profit             51290 non-null  float64
#  14  quantity           51290 non-null  int64
# ...

# %%
df.describe()
# Out:
#            discount   column        profit      quantity         sales  \
# count  51290.000000  51290.0  51290.000000  51290.000000  51290.000000
# mean       0.142908      1.0     28.610982      3.476545    246.498440
# std        0.212280      0.0    174.340972      2.278766    487.567175
# min        0.000000      1.0  -6599.978000      1.000000      0.000000
# 25%        0.000000      1.0      0.000000      2.000000     31.000000
# 50%        0.000000      1.0      9.240000      3.000000     85.000000
# 75%        0.200000      1.0     36.810000      5.000000    251.000000
# max        0.850000      1.0   8399.976000     14.000000  22638.000000
#
#        shipping_cost    order_year   order_month  order_quarter  \
# count   51290.000000  51290.000000  51290.000000   51290.000000
# mean       26.375818   2012.777208      7.522636       2.793235
# std        57.296810      1.098931      3.300056       1.066015
# min         0.002000   2011.000000      1.000000       1.000000
# ...

# %% [markdown]
# # Initial Ovservation
# - The dataset contains retail sales and shipping-related transactional information.
# - a large dataset with 32 columns and 51290 records
# - Date columns require datatype conversion before analysis.
# - The dataset appears mostly clean with no immediate missing and duplicate values.

# %% [markdown]
# # Data cleaning
#
# # Result:
# - Date columns converted successfully to datetime datatype
# - Different date formats required separate conversion logic
# - Dataset structure is now more suitable for analy
# - the column name column is waste so we drop itsis

# %%
df[['order_date','ship_date']].head()
# Out:
#    order_date   ship_date
# 0  07-01-2011  09-01-2011
# 1  21-01-2011  26-01-2011
# 2  05-08-2011  09-08-2011
# 3  05-08-2011  09-08-2011
# 4  29-09-2011  03-10-2011

# %%
df['order_date'] = pd.to_datetime(df['order_date'] , format ='%Y-%m-%d')
df['ship_date'] = pd.to_datetime(df['ship_date'] , format ='%Y-%m-%d')
df[['order_date', 'ship_date']].dtypes
# Out:
# order_date    datetime64[ns]
# ship_date     datetime64[ns]
# dtype: object

# %%
df['category'].unique()
# Out:
# array(['Office Supplies', 'Technology', 'Furniture'], dtype=object)

# %%
df.drop('column',axis = 1 ,inplace =True)

# %% [markdown]
# # Resolving profit margin
# - profit_margin contained invalid spreadsheet error values (#NAME?)
# - Invalid entries were converted to NaN for proper numerical analysis

# %%
df.iloc[:,29].apply(type).value_counts()
# Out:
# profit_margin
# <class 'str'>    51290
# Name: count, dtype: int64

# %%
df['profit_margin'].unique()
# Out:
# array(['49.11', '48.91', '46.87', ..., '30.43', '34.19', '32.45'],
#       dtype=object)

# %%
df['profit_margin'] = pd.to_numeric(df['profit_margin'], errors='coerce')

# %%
df['profit_margin'].dtype
# Out:
# dtype('float64')

# %%
df.to_csv('../data/cleaned_superstore_data.csv' , index =False)
